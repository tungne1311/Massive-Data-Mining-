# %%
import gc
import sys
import numpy as np
import pandas as pd
import faiss
from pathlib import Path
from sentence_transformers import SentenceTransformer

# Paths
SPLITS_TRAIN   = Path("splits/config_id=baseline/train/")
OUTPUT_DIR     = Path("semantic/")
CHECKPOINT_DIR = OUTPUT_DIR / "checkpoints/"

# Hyperparams
MODEL_NAME    = "sentence-transformers/all-MiniLM-L6-v2"
ENCODE_BATCH  = 32

# item_semantic_profile
W_ITEM_TEXT   = 0.6
W_ITEM_REVIEW = 0.4

# item_review_profile filter
MIN_RELIABILITY = 0.3
MIN_TEXT_LEN    = 50

# user_semantic_profile
BETA      = 0.6    # weight cho recent_profile
LAMBDA    = 0.01   # recency decay: exp(-lambda * days_ago)
N_RECENT  = 20     # top-N recent items cho recent_profile


# Helpers
def l2_normalize(v: np.ndarray) -> np.ndarray:
    norm = np.linalg.norm(v)
    return v / (norm + 1e-9)

def get_parquet_files(folder: Path) -> list:
    files = sorted(folder.glob("**/*.parquet"))
    if not files:
        raise FileNotFoundError(f"Không tìm thấy .parquet trong {folder}")
    return files
# Out:
# WARNING:tensorflow:From D:\PyCharm 2025.1.1.1\JupyterProject\.venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
print("\n" + "="*60)
print("BƯỚC 7.1 — Item semantic profiles + FAISS")
print("="*60)
OUTPUT_DIR.mkdir(exist_ok=True)
CHECKPOINT_DIR.mkdir(exist_ok=True)
model    = SentenceTransformer(MODEL_NAME, device="cuda")
dim      = model.get_sentence_embedding_dimension()
index    = faiss.IndexFlatIP(dim)
item_ids = []
seen     = set()

pq_files = get_parquet_files(SPLITS_TRAIN)
print(f"  Tổng file parquet: {len(pq_files)}")

for file_idx, pq_file in enumerate(pq_files):
    ckpt_emb = CHECKPOINT_DIR / f"item_profiles_{file_idx:04d}.npy"
    ckpt_ids = CHECKPOINT_DIR / f"item_ids_{file_idx:04d}.parquet"

    if ckpt_emb.exists() and ckpt_ids.exists():
        print(f"  [{file_idx:04d}] checkpoint có → load và add vào FAISS")
        embs = np.load(ckpt_emb)
        ids  = pd.read_parquet(ckpt_ids)["parent_asin"].tolist()
        if len(embs) > 0:
            index.add(embs.astype("float32"))
        item_ids.extend(ids)
        seen.update(ids)
        del embs, ids; gc.collect()
        continue

    print(f"\n  [{file_idx:04d}] {pq_file.name}")

    # Load text fields
    df_text = pd.read_parquet(
        pq_file,
        columns=["parent_asin", "item_title", "brand", "main_category",  "description", "features"]
    )
    df_text = df_text.drop_duplicates("parent_asin")
    df_text = df_text[~df_text["parent_asin"].isin(seen)].reset_index(drop=True)

    if len(df_text) == 0:
        print(f"    Không có item mới.")
        np.save(ckpt_emb, np.zeros((0, dim), dtype="float32"))
        pd.DataFrame({"parent_asin": []}).to_parquet(ckpt_ids, index=False)
        continue

    df_text["item_text"] = (
        df_text["item_title"].fillna("") + " " +
        df_text["brand"].fillna("") + " " +
        df_text["main_category"].fillna("") + " " +
        df_text["description"].fillna("") + " " +
        df_text["features"].fillna("")
        ).str.strip()
    df_text = df_text[df_text["item_text"].str.len() > 0].reset_index(drop=True)
    print(f"    Item mới: {len(df_text):,}")

    # Encode item_text_emb
    text_embs = model.encode(
        df_text["item_text"].tolist(),
        batch_size=ENCODE_BATCH,
        show_progress_bar=True,
        normalize_embeddings=True,
        convert_to_numpy=True,
    ).astype("float32")

    # Load review_text của file này, filter noise
    df_rev = pd.read_parquet(
        pq_file,
        columns=["parent_asin", "review_text", "text_len",
                 "reliability_score", "strength_score"]
    )
    df_rev = df_rev[
        df_rev["parent_asin"].isin(set(df_text["parent_asin"])) &
        (df_rev["reliability_score"] > MIN_RELIABILITY) &
        (df_rev["text_len"] > MIN_TEXT_LEN)
    ].reset_index(drop=True)
    print(f"    Review sau filter: {len(df_rev):,}")

    # Encode review_text + pool theo item
    item_review_map = {}

    if len(df_rev) > 0:
        rev_embs = model.encode(
            df_rev["review_text"].fillna("").tolist(),
            batch_size=ENCODE_BATCH,
            show_progress_bar=True,
            normalize_embeddings=True,
            convert_to_numpy=True,
        ).astype("float32")

        df_rev = df_rev.reset_index(drop=True)
        df_rev["_eidx"] = range(len(df_rev))

        for asin, grp in df_rev.groupby("parent_asin"):
            idxs   = grp["_eidx"].values
            w      = grp["reliability_score"].values * grp["strength_score"].values
            w      = w / (w.sum() + 1e-9)
            pooled = (rev_embs[idxs] * w[:, None]).sum(axis=0)
            item_review_map[asin] = l2_normalize(pooled)

        del rev_embs; gc.collect()

    del df_rev; gc.collect()

    # Blend: item_semantic_profile
    asin_list     = df_text["parent_asin"].tolist()
    item_profiles = np.zeros((len(asin_list), dim), dtype="float32")

    for j, asin in enumerate(asin_list):
        text_vec   = text_embs[j]
        review_vec = item_review_map.get(asin)

        if review_vec is not None:
            blended = W_ITEM_TEXT * text_vec + W_ITEM_REVIEW * review_vec
        else:
            # Không có review đủ chất lượng → fallback chỉ dùng text
            blended = text_vec

        item_profiles[j] = l2_normalize(blended)

    # Add vào FAISS + lưu checkpoint
    index.add(item_profiles)
    item_ids.extend(asin_list)
    seen.update(asin_list)

    np.save(ckpt_emb, item_profiles)
    pd.DataFrame({"parent_asin": asin_list}).to_parquet(ckpt_ids, index=False)
    print(f"    Saved checkpoint item_profiles_{file_idx:04d}")

    del df_text, text_embs, item_review_map, item_profiles; gc.collect()

# Lưu FAISS + item_id_map
print(f"\n  Tổng item trong FAISS: {index.ntotal:,}")
faiss.write_index(index, str(OUTPUT_DIR / "faiss_index_v1.index"))
pd.DataFrame({
    "parent_asin": item_ids,
    "faiss_pos":   range(len(item_ids))
}).to_parquet(OUTPUT_DIR / "item_id_map_v1.parquet", index=False)

del index; gc.collect()
print("Bước 7.1 hoàn thành!")
# Out:
# ============================================================
# BƯỚC 7.1 — Item semantic profiles + FAISS
# ============================================================
#   Tổng file parquet: 665
#   [0000] checkpoint có → load và add vào FAISS
#   [0001] checkpoint có → load và add vào FAISS
#   [0002] checkpoint có → load và add vào FAISS
#   [0003] checkpoint có → load và add vào FAISS
#   [0004] checkpoint có → load và add vào FAISS
#   [0005] checkpoint có → load và add vào FAISS
#   [0006] checkpoint có → load và add vào FAISS
#   [0007] checkpoint có → load và add vào FAISS
#   [0008] checkpoint có → load và add vào FAISS
#   [0009] checkpoint có → load và add vào FAISS
#   [0010] checkpoint có → load và add vào FAISS
#   [0011] checkpoint có → load và add vào FAISS
#   [0012] checkpoint có → load và add vào FAISS
#   [0013] checkpoint có → load và add vào FAISS
#   [0014] checkpoint có → load và add vào FAISS
#   [0015] checkpoint có → load và add vào FAISS
#   [0016] checkpoint có → load và add vào FAISS
#   [0017] checkpoint có → load và add vào FAISS
#   [0018] checkpoint có → load và add vào FAISS
#   [0019] checkpoint có → load và add vào FAISS
#   [0020] checkpoint có → load và add vào FAISS
#   [0021] checkpoint có → load và add vào FAISS
#   [0022] checkpoint có → load và add vào FAISS
#   [0023] checkpoint có → load và add vào FAISS
#   [0024] checkpoint có → load và add vào FAISS
#   [0025] checkpoint có → load và add vào FAISS
#   [0026] checkpoint có → load và add vào FAISS
#   [0027] checkpoint có → load và add vào FAISS
#   [0028] checkpoint có → load và add vào FAISS
#   [0029] checkpoint có → load và add vào FAISS
#   [0030] checkpoint có → load và add vào FAISS
#   [0031] checkpoint có → load và add vào FAISS
#   [0032] checkpoint có → load và add vào FAISS
#   [0033] checkpoint có → load và add vào FAISS
#   [0034] checkpoint có → load và add vào FAISS
#   [0035] checkpoint có → load và add vào FAISS
#   [0036] checkpoint có → load và add vào FAISS
#   [0037] checkpoint có → load và add vào FAISS
#   [0038] checkpoint có → load và add vào FAISS
#   [0039] checkpoint có → load và add vào FAISS
#   [0040] checkpoint có → load và add vào FAISS
#   [0041] checkpoint có → load và add vào FAISS
#   [0042] checkpoint có → load và add vào FAISS
#   [0043] checkpoint có → load và add vào FAISS
#   [0044] checkpoint có → load và add vào FAISS
#   [0045] checkpoint có → load và add vào FAISS
#   [0046] checkpoint có → load và add vào FAISS
#   [0047] checkpoint có → load và add vào FAISS
#   [0048] checkpoint có → load và add vào FAISS
#   [0049] checkpoint có → load và add vào FAISS
#   [0050] checkpoint có → load và add vào FAISS
#   [0051] checkpoint có → load và add vào FAISS
#   [0052] checkpoint có → load và add vào FAISS
#   [0053] checkpoint có → load và add vào FAISS
#   [0054] checkpoint có → load và add vào FAISS
#   [0055] checkpoint có → load và add vào FAISS
#   [0056] checkpoint có → load và add vào FAISS
#   [0057] checkpoint có → load và add vào FAISS
#   [0058] checkpoint có → load và add vào FAISS
#   [0059] checkpoint có → load và add vào FAISS
#   [0060] checkpoint có → load và add vào FAISS
#   [0061] checkpoint có → load và add vào FAISS
#   [0062] checkpoint có → load và add vào FAISS
#   [0063] checkpoint có → load và add vào FAISS
#   [0064] checkpoint có → load và add vào FAISS
#   [0065] checkpoint có → load và add vào FAISS
#   [0066] checkpoint có → load và add vào FAISS
#   [0067] checkpoint có → load và add vào FAISS
#   [0068] checkpoint có → load và add vào FAISS
#   [0069] checkpoint có → load và add vào FAISS
#   [0070] checkpoint có → load và add vào FAISS
#   [0071] checkpoint có → load và add vào FAISS
#   [0072] checkpoint có → load và add vào FAISS
#   [0073] checkpoint có → load và add vào FAISS
#   [0074] checkpoint có → load và add vào FAISS
#   [0075] checkpoint có → load và add vào FAISS
#   [0076] checkpoint có → load và add vào FAISS
#   [0077] checkpoint có → load và add vào FAISS
#   [0078] checkpoint có → load và add vào FAISS
#   [0079] checkpoint có → load và add vào FAISS
#   [0080] checkpoint có → load và add vào FAISS
#   [0081] checkpoint có → load và add vào FAISS
#   [0082] checkpoint có → load và add vào FAISS
#   [0083] checkpoint có → load và add vào FAISS
#   [0084] checkpoint có → load và add vào FAISS
#   [0085] checkpoint có → load và add vào FAISS
#   [0086] checkpoint có → load và add vào FAISS
#   [0087] checkpoint có → load và add vào FAISS
#   [0088] checkpoint có → load và add vào FAISS
#   [0089] checkpoint có → load và add vào FAISS
#   [0090] checkpoint có → load và add vào FAISS
#   [0091] checkpoint có → load và add vào FAISS
#   [0092] checkpoint có → load và add vào FAISS
#   [0093] checkpoint có → load và add vào FAISS
#   [0094] checkpoint có → load và add vào FAISS
#   [0095] checkpoint có → load và add vào FAISS
#   [0096] checkpoint có → load và add vào FAISS
#   [0097] checkpoint có → load và add vào FAISS
#   [0098] checkpoint có → load và add vào FAISS
#   [0099] checkpoint có → load và add vào FAISS
#   [0100] checkpoint có → load và add vào FAISS
#   [0101] checkpoint có → load và add vào FAISS
#   [0102] checkpoint có → load và add vào FAISS
#   [0103] checkpoint có → load và add vào FAISS
#   [0104] checkpoint có → load và add vào FAISS
#   [0105] checkpoint có → load và add vào FAISS
#   [0106] checkpoint có → load và add vào FAISS
#   [0107] checkpoint có → load và add vào FAISS
#   [0108] checkpoint có → load và add vào FAISS
#   [0109] checkpoint có → load và add vào FAISS
#   [0110] checkpoint có → load và add vào FAISS
#   [0111] checkpoint có → load và add vào FAISS
#   [0112] checkpoint có → load và add vào FAISS
#   [0113] checkpoint có → load và add vào FAISS
#   [0114] checkpoint có → load và add vào FAISS
#   [0115] checkpoint có → load và add vào FAISS
#   [0116] checkpoint có → load và add vào FAISS
#   [0117] checkpoint có → load và add vào FAISS
#   [0118] checkpoint có → load và add vào FAISS
#   [0119] checkpoint có → load và add vào FAISS
#   [0120] checkpoint có → load và add vào FAISS
#   [0121] checkpoint có → load và add vào FAISS
#   [0122] checkpoint có → load và add vào FAISS
#   [0123] checkpoint có → load và add vào FAISS
#   [0124] checkpoint có → load và add vào FAISS
#   [0125] checkpoint có → load và add vào FAISS
#   [0126] checkpoint có → load và add vào FAISS
#   [0127] checkpoint có → load và add vào FAISS
#   [0128] checkpoint có → load và add vào FAISS
#   [0129] checkpoint có → load và add vào FAISS
#   [0130] checkpoint có → load và add vào FAISS
#   [0131] checkpoint có → load và add vào FAISS
#   [0132] checkpoint có → load và add vào FAISS
#   [0133] checkpoint có → load và add vào FAISS
#   [0134] checkpoint có → load và add vào FAISS
#   [0135] checkpoint có → load và add vào FAISS
#   [0136] checkpoint có → load và add vào FAISS
#   [0137] checkpoint có → load và add vào FAISS
#   [0138] checkpoint có → load và add vào FAISS
#   [0139] checkpoint có → load và add vào FAISS
#   [0140] checkpoint có → load và add vào FAISS
#   [0141] checkpoint có → load và add vào FAISS
#   [0142] checkpoint có → load và add vào FAISS
#   [0143] checkpoint có → load và add vào FAISS
#   [0144] checkpoint có → load và add vào FAISS
#   [0145] checkpoint có → load và add vào FAISS
#   [0146] checkpoint có → load và add vào FAISS
#   [0147] checkpoint có → load và add vào FAISS
#   [0148] checkpoint có → load và add vào FAISS
#   [0149] checkpoint có → load và add vào FAISS
#   [0150] checkpoint có → load và add vào FAISS
#   [0151] checkpoint có → load và add vào FAISS
#   [0152] checkpoint có → load và add vào FAISS
#   [0153] checkpoint có → load và add vào FAISS
#   [0154] checkpoint có → load và add vào FAISS
#   [0155] checkpoint có → load và add vào FAISS
#   [0156] checkpoint có → load và add vào FAISS
#   [0157] checkpoint có → load và add vào FAISS
#   [0158] checkpoint có → load và add vào FAISS
#   [0159] checkpoint có → load và add vào FAISS
#   [0160] checkpoint có → load và add vào FAISS
#   [0161] checkpoint có → load và add vào FAISS
#   [0162] checkpoint có → load và add vào FAISS
#   [0163] checkpoint có → load và add vào FAISS
#   [0164] checkpoint có → load và add vào FAISS
#   [0165] checkpoint có → load và add vào FAISS
#   [0166] checkpoint có → load và add vào FAISS
#   [0167] checkpoint có → load và add vào FAISS
#   [0168] checkpoint có → load và add vào FAISS
#   [0169] checkpoint có → load và add vào FAISS
#   [0170] checkpoint có → load và add vào FAISS
#   [0171] checkpoint có → load và add vào FAISS
#   [0172] checkpoint có → load và add vào FAISS
#   [0173] checkpoint có → load và add vào FAISS
#   [0174] checkpoint có → load và add vào FAISS
#   [0175] checkpoint có → load và add vào FAISS
#   [0176] checkpoint có → load và add vào FAISS
#   [0177] checkpoint có → load và add vào FAISS
#   [0178] checkpoint có → load và add vào FAISS
#   [0179] checkpoint có → load và add vào FAISS
#   [0180] checkpoint có → load và add vào FAISS
#   [0181] checkpoint có → load và add vào FAISS
#   [0182] checkpoint có → load và add vào FAISS
#   [0183] checkpoint có → load và add vào FAISS
#   [0184] checkpoint có → load và add vào FAISS
#   [0185] checkpoint có → load và add vào FAISS
#   [0186] checkpoint có → load và add vào FAISS
#   [0187] checkpoint có → load và add vào FAISS
#   [0188] checkpoint có → load và add vào FAISS
#   [0189] checkpoint có → load và add vào FAISS
#   [0190] checkpoint có → load và add vào FAISS
#   [0191] checkpoint có → load và add vào FAISS
#   [0192] checkpoint có → load và add vào FAISS
#   [0193] checkpoint có → load và add vào FAISS
#   [0194] checkpoint có → load và add vào FAISS
#   [0195] checkpoint có → load và add vào FAISS
#   [0196] checkpoint có → load và add vào FAISS
#   [0197] checkpoint có → load và add vào FAISS
#   [0198] checkpoint có → load và add vào FAISS
#   [0199] checkpoint có → load và add vào FAISS
#   [0200] checkpoint có → load và add vào FAISS
#   [0201] checkpoint có → load và add vào FAISS
#   [0202] checkpoint có → load và add vào FAISS
#   [0203] checkpoint có → load và add vào FAISS
#   [0204] checkpoint có → load và add vào FAISS
#   [0205] checkpoint có → load và add vào FAISS
#   [0206] checkpoint có → load và add vào FAISS
#   [0207] checkpoint có → load và add vào FAISS
#   [0208] checkpoint có → load và add vào FAISS
#   [0209] checkpoint có → load và add vào FAISS
#   [0210] checkpoint có → load và add vào FAISS
#   [0211] checkpoint có → load và add vào FAISS
#   [0212] checkpoint có → load và add vào FAISS
#   [0213] checkpoint có → load và add vào FAISS
#   [0214] checkpoint có → load và add vào FAISS
#   [0215] checkpoint có → load và add vào FAISS
#   [0216] checkpoint có → load và add vào FAISS
#   [0217] checkpoint có → load và add vào FAISS
#   [0218] checkpoint có → load và add vào FAISS
#   [0219] checkpoint có → load và add vào FAISS
#   [0220] checkpoint có → load và add vào FAISS
#   [0221] checkpoint có → load và add vào FAISS
#   [0222] checkpoint có → load và add vào FAISS
#   [0223] checkpoint có → load và add vào FAISS
#   [0224] checkpoint có → load và add vào FAISS
#   [0225] checkpoint có → load và add vào FAISS
#   [0226] checkpoint có → load và add vào FAISS
#   [0227] checkpoint có → load và add vào FAISS
#   [0228] checkpoint có → load và add vào FAISS
#   [0229] checkpoint có → load và add vào FAISS
#   [0230] checkpoint có → load và add vào FAISS
#   [0231] checkpoint có → load và add vào FAISS
#   [0232] checkpoint có → load và add vào FAISS
#   [0233] checkpoint có → load và add vào FAISS
#   [0234] checkpoint có → load và add vào FAISS
#   [0235] checkpoint có → load và add vào FAISS
#   [0236] checkpoint có → load và add vào FAISS
#   [0237] checkpoint có → load và add vào FAISS
#   [0238] checkpoint có → load và add vào FAISS
#   [0239] checkpoint có → load và add vào FAISS
#   [0240] checkpoint có → load và add vào FAISS
#   [0241] checkpoint có → load và add vào FAISS
#   [0242] checkpoint có → load và add vào FAISS
#   [0243] checkpoint có → load và add vào FAISS
#   [0244] checkpoint có → load và add vào FAISS
#   [0245] checkpoint có → load và add vào FAISS
#   [0246] checkpoint có → load và add vào FAISS
#   [0247] checkpoint có → load và add vào FAISS
#   [0248] checkpoint có → load và add vào FAISS
#   [0249] checkpoint có → load và add vào FAISS
#   [0250] checkpoint có → load và add vào FAISS
#   [0251] checkpoint có → load và add vào FAISS
#   [0252] checkpoint có → load và add vào FAISS
#   [0253] checkpoint có → load và add vào FAISS
#   [0254] checkpoint có → load và add vào FAISS
#   [0255] checkpoint có → load và add vào FAISS
#   [0256] checkpoint có → load và add vào FAISS
#   [0257] checkpoint có → load và add vào FAISS
#   [0258] checkpoint có → load và add vào FAISS
#   [0259] checkpoint có → load và add vào FAISS
#   [0260] checkpoint có → load và add vào FAISS
#   [0261] checkpoint có → load và add vào FAISS
#   [0262] checkpoint có → load và add vào FAISS
#   [0263] checkpoint có → load và add vào FAISS
#   [0264] checkpoint có → load và add vào FAISS
#   [0265] checkpoint có → load và add vào FAISS
#   [0266] checkpoint có → load và add vào FAISS
#   [0267] checkpoint có → load và add vào FAISS
#   [0268] checkpoint có → load và add vào FAISS
#   [0269] checkpoint có → load và add vào FAISS
#   [0270] checkpoint có → load và add vào FAISS
#   [0271] checkpoint có → load và add vào FAISS
#   [0272] checkpoint có → load và add vào FAISS
#   [0273] checkpoint có → load và add vào FAISS
#   [0274] checkpoint có → load và add vào FAISS
#   [0275] checkpoint có → load và add vào FAISS
#   [0276] checkpoint có → load và add vào FAISS
#   [0277] checkpoint có → load và add vào FAISS
#   [0278] checkpoint có → load và add vào FAISS
#   [0279] checkpoint có → load và add vào FAISS
#   [0280] checkpoint có → load và add vào FAISS
#   [0281] checkpoint có → load và add vào FAISS
#   [0282] checkpoint có → load và add vào FAISS
#   [0283] checkpoint có → load và add vào FAISS
#   [0284] checkpoint có → load và add vào FAISS
#   [0285] checkpoint có → load và add vào FAISS
#   [0286] checkpoint có → load và add vào FAISS
#   [0287] checkpoint có → load và add vào FAISS
#   [0288] checkpoint có → load và add vào FAISS
#   [0289] checkpoint có → load và add vào FAISS
#   [0290] checkpoint có → load và add vào FAISS
#   [0291] checkpoint có → load và add vào FAISS
#   [0292] checkpoint có → load và add vào FAISS
#   [0293] checkpoint có → load và add vào FAISS
#   [0294] checkpoint có → load và add vào FAISS
#   [0295] checkpoint có → load và add vào FAISS
#   [0296] checkpoint có → load và add vào FAISS
#   [0297] checkpoint có → load và add vào FAISS
#   [0298] checkpoint có → load và add vào FAISS
#   [0299] checkpoint có → load và add vào FAISS
#   [0300] checkpoint có → load và add vào FAISS
#   [0301] checkpoint có → load và add vào FAISS
#   [0302] checkpoint có → load và add vào FAISS
#   [0303] checkpoint có → load và add vào FAISS
#   [0304] checkpoint có → load và add vào FAISS
#   [0305] checkpoint có → load và add vào FAISS
#   [0306] checkpoint có → load và add vào FAISS
#   [0307] checkpoint có → load và add vào FAISS
#   [0308] checkpoint có → load và add vào FAISS
#   [0309] checkpoint có → load và add vào FAISS
#   [0310] checkpoint có → load và add vào FAISS
#   [0311] checkpoint có → load và add vào FAISS
#   [0312] checkpoint có → load và add vào FAISS
#   [0313] checkpoint có → load và add vào FAISS
#   [0314] checkpoint có → load và add vào FAISS
#   [0315] checkpoint có → load và add vào FAISS
#   [0316] checkpoint có → load và add vào FAISS
#   [0317] checkpoint có → load và add vào FAISS
#   [0318] checkpoint có → load và add vào FAISS
#   [0319] checkpoint có → load và add vào FAISS
#   [0320] checkpoint có → load và add vào FAISS
#   [0321] checkpoint có → load và add vào FAISS
#   [0322] checkpoint có → load và add vào FAISS
#   [0323] checkpoint có → load và add vào FAISS
#   [0324] checkpoint có → load và add vào FAISS
#   [0325] checkpoint có → load và add vào FAISS
#   [0326] checkpoint có → load và add vào FAISS
#   [0327] checkpoint có → load và add vào FAISS
#   [0328] checkpoint có → load và add vào FAISS
#   [0329] checkpoint có → load và add vào FAISS
#   [0330] checkpoint có → load và add vào FAISS
#   [0331] checkpoint có → load và add vào FAISS
#   [0332] checkpoint có → load và add vào FAISS
#   [0333] checkpoint có → load và add vào FAISS
#   [0334] checkpoint có → load và add vào FAISS
#   [0335] checkpoint có → load và add vào FAISS
#   [0336] checkpoint có → load và add vào FAISS
#   [0337] checkpoint có → load và add vào FAISS
#   [0338] checkpoint có → load và add vào FAISS
#   [0339] checkpoint có → load và add vào FAISS
#   [0340] checkpoint có → load và add vào FAISS
#   [0341] checkpoint có → load và add vào FAISS
#   [0342] checkpoint có → load và add vào FAISS
#   [0343] checkpoint có → load và add vào FAISS
#   [0344] checkpoint có → load và add vào FAISS
#   [0345] checkpoint có → load và add vào FAISS
#   [0346] checkpoint có → load và add vào FAISS
#   [0347] checkpoint có → load và add vào FAISS
#   [0348] checkpoint có → load và add vào FAISS
#   [0349] checkpoint có → load và add vào FAISS
#   [0350] checkpoint có → load và add vào FAISS
#   [0351] checkpoint có → load và add vào FAISS
#   [0352] checkpoint có → load và add vào FAISS
#   [0353] checkpoint có → load và add vào FAISS
#   [0354] checkpoint có → load và add vào FAISS
#   [0355] checkpoint có → load và add vào FAISS
#   [0356] checkpoint có → load và add vào FAISS
#   [0357] checkpoint có → load và add vào FAISS
#   [0358] checkpoint có → load và add vào FAISS
#   [0359] checkpoint có → load và add vào FAISS
#   [0360] checkpoint có → load và add vào FAISS
#   [0361] checkpoint có → load và add vào FAISS
#   [0362] checkpoint có → load và add vào FAISS
#   [0363] checkpoint có → load và add vào FAISS
#   [0364] checkpoint có → load và add vào FAISS
#   [0365] checkpoint có → load và add vào FAISS
#   [0366] checkpoint có → load và add vào FAISS
#   [0367] checkpoint có → load và add vào FAISS
#   [0368] checkpoint có → load và add vào FAISS
#   [0369] checkpoint có → load và add vào FAISS
#   [0370] checkpoint có → load và add vào FAISS
#   [0371] checkpoint có → load và add vào FAISS
#   [0372] checkpoint có → load và add vào FAISS
#   [0373] checkpoint có → load và add vào FAISS
#   [0374] checkpoint có → load và add vào FAISS
#   [0375] checkpoint có → load và add vào FAISS
#   [0376] checkpoint có → load và add vào FAISS
#   [0377] checkpoint có → load và add vào FAISS
#   [0378] checkpoint có → load và add vào FAISS
#   [0379] checkpoint có → load và add vào FAISS
#   [0380] checkpoint có → load và add vào FAISS
#   [0381] checkpoint có → load và add vào FAISS
#   [0382] checkpoint có → load và add vào FAISS
#   [0383] checkpoint có → load và add vào FAISS
#   [0384] checkpoint có → load và add vào FAISS
#   [0385] checkpoint có → load và add vào FAISS
#   [0386] checkpoint có → load và add vào FAISS
#   [0387] checkpoint có → load và add vào FAISS
#   [0388] checkpoint có → load và add vào FAISS
#   [0389] checkpoint có → load và add vào FAISS
#   [0390] checkpoint có → load và add vào FAISS
#   [0391] checkpoint có → load và add vào FAISS
#   [0392] checkpoint có → load và add vào FAISS
#   [0393] checkpoint có → load và add vào FAISS
#   [0394] checkpoint có → load và add vào FAISS
#   [0395] checkpoint có → load và add vào FAISS
#   [0396] checkpoint có → load và add vào FAISS
#   [0397] checkpoint có → load và add vào FAISS
#   [0398] checkpoint có → load và add vào FAISS
#   [0399] checkpoint có → load và add vào FAISS
#   [0400] checkpoint có → load và add vào FAISS
#   [0401] checkpoint có → load và add vào FAISS
#   [0402] checkpoint có → load và add vào FAISS
#   [0403] checkpoint có → load và add vào FAISS
#   [0404] checkpoint có → load và add vào FAISS
#   [0405] checkpoint có → load và add vào FAISS
#   [0406] checkpoint có → load và add vào FAISS
#   [0407] checkpoint có → load và add vào FAISS
#   [0408] checkpoint có → load và add vào FAISS
#   [0409] checkpoint có → load và add vào FAISS
#   [0410] checkpoint có → load và add vào FAISS
#   [0411] checkpoint có → load và add vào FAISS
#   [0412] checkpoint có → load và add vào FAISS
#   [0413] checkpoint có → load và add vào FAISS
#   [0414] checkpoint có → load và add vào FAISS
#   [0415] checkpoint có → load và add vào FAISS
#   [0416] checkpoint có → load và add vào FAISS
#   [0417] checkpoint có → load và add vào FAISS
#   [0418] checkpoint có → load và add vào FAISS
#   [0419] checkpoint có → load và add vào FAISS
#   [0420] checkpoint có → load và add vào FAISS
#   [0421] checkpoint có → load và add vào FAISS
#   [0422] checkpoint có → load và add vào FAISS
#   [0423] checkpoint có → load và add vào FAISS
#   [0424] checkpoint có → load và add vào FAISS
#   [0425] checkpoint có → load và add vào FAISS
#   [0426] checkpoint có → load và add vào FAISS
#   [0427] checkpoint có → load và add vào FAISS
#   [0428] checkpoint có → load và add vào FAISS
#   [0429] checkpoint có → load và add vào FAISS
#   [0430] checkpoint có → load và add vào FAISS
#   [0431] checkpoint có → load và add vào FAISS
#   [0432] checkpoint có → load và add vào FAISS
#   [0433] checkpoint có → load và add vào FAISS
#   [0434] checkpoint có → load và add vào FAISS
#   [0435] checkpoint có → load và add vào FAISS
#   [0436] checkpoint có → load và add vào FAISS
#   [0437] checkpoint có → load và add vào FAISS
#   [0438] checkpoint có → load và add vào FAISS
#   [0439] checkpoint có → load và add vào FAISS
#   [0440] checkpoint có → load và add vào FAISS
#   [0441] checkpoint có → load và add vào FAISS
#   [0442] checkpoint có → load và add vào FAISS
#   [0443] checkpoint có → load và add vào FAISS
#   [0444] checkpoint có → load và add vào FAISS
#   [0445] checkpoint có → load và add vào FAISS
#   [0446] checkpoint có → load và add vào FAISS
#   [0447] checkpoint có → load và add vào FAISS
#   [0448] checkpoint có → load và add vào FAISS
#   [0449] checkpoint có → load và add vào FAISS
#   [0450] checkpoint có → load và add vào FAISS
#   [0451] checkpoint có → load và add vào FAISS
#   [0452] checkpoint có → load và add vào FAISS
#   [0453] checkpoint có → load và add vào FAISS
#   [0454] checkpoint có → load và add vào FAISS
#   [0455] checkpoint có → load và add vào FAISS
#   [0456] checkpoint có → load và add vào FAISS
#   [0457] checkpoint có → load và add vào FAISS
#   [0458] checkpoint có → load và add vào FAISS
#   [0459] checkpoint có → load và add vào FAISS
#   [0460] checkpoint có → load và add vào FAISS
#   [0461] checkpoint có → load và add vào FAISS
#   [0462] checkpoint có → load và add vào FAISS
#   [0463] checkpoint có → load và add vào FAISS
#   [0464] checkpoint có → load và add vào FAISS
#   [0465] checkpoint có → load và add vào FAISS
#   [0466] checkpoint có → load và add vào FAISS
#   [0467] checkpoint có → load và add vào FAISS
#   [0468] checkpoint có → load và add vào FAISS
#   [0469] checkpoint có → load và add vào FAISS
#   [0470] checkpoint có → load và add vào FAISS
#   [0471] checkpoint có → load và add vào FAISS
#   [0472] checkpoint có → load và add vào FAISS
#   [0473] checkpoint có → load và add vào FAISS
#   [0474] checkpoint có → load và add vào FAISS
#   [0475] checkpoint có → load và add vào FAISS
#   [0476] checkpoint có → load và add vào FAISS
#   [0477] checkpoint có → load và add vào FAISS
#   [0478] checkpoint có → load và add vào FAISS
#   [0479] checkpoint có → load và add vào FAISS
#   [0480] checkpoint có → load và add vào FAISS
#   [0481] checkpoint có → load và add vào FAISS
#   [0482] checkpoint có → load và add vào FAISS
#   [0483] checkpoint có → load và add vào FAISS
#   [0484] checkpoint có → load và add vào FAISS
#   [0485] checkpoint có → load và add vào FAISS
#   [0486] checkpoint có → load và add vào FAISS
#   [0487] checkpoint có → load và add vào FAISS
#   [0488] checkpoint có → load và add vào FAISS
#   [0489] checkpoint có → load và add vào FAISS
#   [0490] checkpoint có → load và add vào FAISS
#   [0491] checkpoint có → load và add vào FAISS
#   [0492] checkpoint có → load và add vào FAISS
#   [0493] checkpoint có → load và add vào FAISS
#   [0494] checkpoint có → load và add vào FAISS
#   [0495] checkpoint có → load và add vào FAISS
#   [0496] checkpoint có → load và add vào FAISS
#   [0497] checkpoint có → load và add vào FAISS
#   [0498] checkpoint có → load và add vào FAISS
#   [0499] checkpoint có → load và add vào FAISS
#   [0500] checkpoint có → load và add vào FAISS
#   [0501] checkpoint có → load và add vào FAISS
#   [0502] checkpoint có → load và add vào FAISS
#   [0503] checkpoint có → load và add vào FAISS
#   [0504] checkpoint có → load và add vào FAISS
#   [0505] checkpoint có → load và add vào FAISS
#   [0506] checkpoint có → load và add vào FAISS
#   [0507] checkpoint có → load và add vào FAISS
#   [0508] checkpoint có → load và add vào FAISS
#   [0509] checkpoint có → load và add vào FAISS
#   [0510] checkpoint có → load và add vào FAISS
#   [0511] checkpoint có → load và add vào FAISS
#   [0512] checkpoint có → load và add vào FAISS
#   [0513] checkpoint có → load và add vào FAISS
#   [0514] checkpoint có → load và add vào FAISS
#   [0515] checkpoint có → load và add vào FAISS
#   [0516] checkpoint có → load và add vào FAISS
#   [0517] checkpoint có → load và add vào FAISS
#   [0518] checkpoint có → load và add vào FAISS
#   [0519] checkpoint có → load và add vào FAISS
#   [0520] checkpoint có → load và add vào FAISS
#   [0521] checkpoint có → load và add vào FAISS
#   [0522] checkpoint có → load và add vào FAISS
#   [0523] checkpoint có → load và add vào FAISS
#   [0524] checkpoint có → load và add vào FAISS
#   [0525] checkpoint có → load và add vào FAISS
#   [0526] checkpoint có → load và add vào FAISS
#   [0527] checkpoint có → load và add vào FAISS
#   [0528] checkpoint có → load và add vào FAISS
#   [0529] checkpoint có → load và add vào FAISS
#   [0530] checkpoint có → load và add vào FAISS
#   [0531] checkpoint có → load và add vào FAISS
#   [0532] checkpoint có → load và add vào FAISS
#   [0533] checkpoint có → load và add vào FAISS
#   [0534] checkpoint có → load và add vào FAISS
#   [0535] checkpoint có → load và add vào FAISS
#   [0536] checkpoint có → load và add vào FAISS
#   [0537] checkpoint có → load và add vào FAISS
#   [0538] checkpoint có → load và add vào FAISS
#   [0539] checkpoint có → load và add vào FAISS
#   [0540] checkpoint có → load và add vào FAISS
#   [0541] checkpoint có → load và add vào FAISS
#   [0542] checkpoint có → load và add vào FAISS
#   [0543] checkpoint có → load và add vào FAISS
#   [0544] checkpoint có → load và add vào FAISS
#   [0545] checkpoint có → load và add vào FAISS
#   [0546] checkpoint có → load và add vào FAISS
#   [0547] checkpoint có → load và add vào FAISS
#   [0548] checkpoint có → load và add vào FAISS
#   [0549] checkpoint có → load và add vào FAISS
#   [0550] checkpoint có → load và add vào FAISS
#   [0551] checkpoint có → load và add vào FAISS
#   [0552] checkpoint có → load và add vào FAISS
#   [0553] checkpoint có → load và add vào FAISS
#   [0554] checkpoint có → load và add vào FAISS
#   [0555] checkpoint có → load và add vào FAISS
#   [0556] checkpoint có → load và add vào FAISS
#   [0557] checkpoint có → load và add vào FAISS
#   [0558] checkpoint có → load và add vào FAISS
#   [0559] checkpoint có → load và add vào FAISS
#   [0560] checkpoint có → load và add vào FAISS
#   [0561] checkpoint có → load và add vào FAISS
#   [0562] checkpoint có → load và add vào FAISS
#   [0563] checkpoint có → load và add vào FAISS
#   [0564] checkpoint có → load và add vào FAISS
#   [0565] checkpoint có → load và add vào FAISS
#   [0566] checkpoint có → load và add vào FAISS
#   [0567] checkpoint có → load và add vào FAISS
#   [0568] checkpoint có → load và add vào FAISS
#   [0569] checkpoint có → load và add vào FAISS
#   [0570] checkpoint có → load và add vào FAISS
#   [0571] checkpoint có → load và add vào FAISS
#   [0572] checkpoint có → load và add vào FAISS
#   [0573] checkpoint có → load và add vào FAISS
#   [0574] checkpoint có → load và add vào FAISS
#   [0575] checkpoint có → load và add vào FAISS
#   [0576] checkpoint có → load và add vào FAISS
#   [0577] checkpoint có → load và add vào FAISS
#   [0578] checkpoint có → load và add vào FAISS
#   [0579] checkpoint có → load và add vào FAISS
#   [0580] checkpoint có → load và add vào FAISS
#   [0581] checkpoint có → load và add vào FAISS
#   [0582] checkpoint có → load và add vào FAISS
#   [0583] checkpoint có → load và add vào FAISS
#   [0584] checkpoint có → load và add vào FAISS
#   [0585] checkpoint có → load và add vào FAISS
#   [0586] checkpoint có → load và add vào FAISS
#   [0587] checkpoint có → load và add vào FAISS
#   [0588] checkpoint có → load và add vào FAISS
#   [0589] checkpoint có → load và add vào FAISS
#   [0590] checkpoint có → load và add vào FAISS
#   [0591] checkpoint có → load và add vào FAISS
#   [0592] checkpoint có → load và add vào FAISS
#   [0593] checkpoint có → load và add vào FAISS
#   [0594] checkpoint có → load và add vào FAISS
#   [0595] checkpoint có → load và add vào FAISS
#   [0596] checkpoint có → load và add vào FAISS
#   [0597] checkpoint có → load và add vào FAISS
#   [0598] checkpoint có → load và add vào FAISS
#   [0599] checkpoint có → load và add vào FAISS
#   [0600] checkpoint có → load và add vào FAISS
#   [0601] checkpoint có → load và add vào FAISS
#   [0602] checkpoint có → load và add vào FAISS
#   [0603] checkpoint có → load và add vào FAISS
#   [0604] checkpoint có → load và add vào FAISS
#   [0605] checkpoint có → load và add vào FAISS
#   [0606] checkpoint có → load và add vào FAISS
#   [0607] checkpoint có → load và add vào FAISS
#   [0608] checkpoint có → load và add vào FAISS
#   [0609] checkpoint có → load và add vào FAISS
#   [0610] checkpoint có → load và add vào FAISS
#   [0611] checkpoint có → load và add vào FAISS
#   [0612] checkpoint có → load và add vào FAISS
#   [0613] checkpoint có → load và add vào FAISS
#   [0614] checkpoint có → load và add vào FAISS
#   [0615] checkpoint có → load và add vào FAISS
#   [0616] checkpoint có → load và add vào FAISS
#   [0617] checkpoint có → load và add vào FAISS
#   [0618] checkpoint có → load và add vào FAISS
#   [0619] checkpoint có → load và add vào FAISS
#   [0620] checkpoint có → load và add vào FAISS
#   [0621] checkpoint có → load và add vào FAISS
#   [0622] checkpoint có → load và add vào FAISS
#   [0623] checkpoint có → load và add vào FAISS
#   [0624] checkpoint có → load và add vào FAISS
#   [0625] checkpoint có → load và add vào FAISS
#   [0626] checkpoint có → load và add vào FAISS
#   [0627] checkpoint có → load và add vào FAISS
#   [0628] checkpoint có → load và add vào FAISS
#   [0629] checkpoint có → load và add vào FAISS
#   [0630] checkpoint có → load và add vào FAISS
#   [0631] checkpoint có → load và add vào FAISS
#   [0632] checkpoint có → load và add vào FAISS
#   [0633] checkpoint có → load và add vào FAISS
#   [0634] checkpoint có → load và add vào FAISS
#   [0635] checkpoint có → load và add vào FAISS
#   [0636] checkpoint có → load và add vào FAISS
#   [0637] checkpoint có → load và add vào FAISS
#   [0638] checkpoint có → load và add vào FAISS
#   [0639] checkpoint có → load và add vào FAISS
#   [0640] checkpoint có → load và add vào FAISS
#   [0641] checkpoint có → load và add vào FAISS
#   [0642] checkpoint có → load và add vào FAISS
#   [0643] checkpoint có → load và add vào FAISS
#   [0644] checkpoint có → load và add vào FAISS
#   [0645] checkpoint có → load và add vào FAISS
#   [0646] checkpoint có → load và add vào FAISS
#   [0647] checkpoint có → load và add vào FAISS
#   [0648] checkpoint có → load và add vào FAISS
#   [0649] checkpoint có → load và add vào FAISS
#   [0650] checkpoint có → load và add vào FAISS
#   [0651] checkpoint có → load và add vào FAISS
#   [0652] checkpoint có → load và add vào FAISS
#   [0653] checkpoint có → load và add vào FAISS
#   [0654] checkpoint có → load và add vào FAISS
#   [0655] checkpoint có → load và add vào FAISS
#   [0656] checkpoint có → load và add vào FAISS
#   [0657] checkpoint có → load và add vào FAISS
#   [0658] checkpoint có → load và add vào FAISS
#   [0659] checkpoint có → load và add vào FAISS
#   [0660] checkpoint có → load và add vào FAISS
#   [0661] checkpoint có → load và add vào FAISS
#   [0662] checkpoint có → load và add vào FAISS
#   [0663] checkpoint có → load và add vào FAISS
#   [0664] checkpoint có → load và add vào FAISS
#
#   Tổng item trong FAISS: 1,602,487
# Bước 7.1 hoàn thành!

# %%
print("\n" + "="*60)
print("BƯỚC 7.2 — Encode review_text cho user profiles")
print("="*60)
OUTPUT_DIR.mkdir(exist_ok=True)
CHECKPOINT_DIR.mkdir(exist_ok=True)
model = SentenceTransformer(MODEL_NAME, device="cuda")
dim   = model.get_sentence_embedding_dimension()

COLS = ["reviewer_id", "parent_asin", "review_text", "text_len",
        "reliability_score", "strength_score", "review_time",
        "bpr_role", "interaction_type"]

pq_files   = get_parquet_files(SPLITS_TRAIN)
meta_parts = []
global_idx = 0

for file_idx, pq_file in enumerate(pq_files):
    ckpt_emb  = CHECKPOINT_DIR / f"user_rev_{file_idx:04d}_emb.npy"
    ckpt_meta = CHECKPOINT_DIR / f"user_rev_{file_idx:04d}_meta.parquet"

    if ckpt_emb.exists() and ckpt_meta.exists():
        print(f"  [{file_idx:04d}] checkpoint có → bỏ qua")
        saved = pd.read_parquet(ckpt_meta)
        meta_parts.append(saved)
        global_idx += len(saved)
        del saved; gc.collect()
        continue

    print(f"\n  [{file_idx:04d}] {pq_file.name}")
    df = pd.read_parquet(pq_file, columns=COLS)

    df_pos = df[
        (df["bpr_role"] == "positive") &
        (df["reliability_score"] > MIN_RELIABILITY) &
        (df["text_len"] > MIN_TEXT_LEN) &
        (df["interaction_type"].isin(["strong_positive", "weak_positive"]))
    ].copy().reset_index(drop=True)
    del df; gc.collect()

    if len(df_pos) == 0:
        print(f"    Không có row hợp lệ.")
        np.save(ckpt_emb, np.zeros((0, dim), dtype="float32"))
        pd.DataFrame(columns=["reviewer_id", "parent_asin", "emb_idx",
                               "reliability_score", "strength_score",
                               "review_time"]).to_parquet(ckpt_meta, index=False)
        continue

    print(f"    Rows sau filter: {len(df_pos):,}")

    embs = model.encode(
        df_pos["review_text"].fillna("").tolist(),
        batch_size=ENCODE_BATCH,
        show_progress_bar=True,
        normalize_embeddings=True,
        convert_to_numpy=True,
    ).astype("float32")

    df_pos["emb_idx"] = range(global_idx, global_idx + len(df_pos))
    global_idx += len(df_pos)

    meta = df_pos[["reviewer_id", "parent_asin", "emb_idx",
                    "reliability_score", "strength_score", "review_time"]].copy()
    np.save(ckpt_emb, embs)
    meta.to_parquet(ckpt_meta, index=False)
    meta_parts.append(meta)

    del df_pos, embs, meta; gc.collect()
    print(f"    Saved user_rev_{file_idx:04d}_*")

print("\n  Gộp review_meta...")
pd.concat(meta_parts, ignore_index=True) \
  .to_parquet(OUTPUT_DIR / "review_meta.parquet", index=False)

#done_flag.touch()
print("Bước 7.2 hoàn thành!")
# Out:
# ============================================================
# BƯỚC 7.2 — Encode review_text cho user profiles
# ============================================================
#   [0000] checkpoint có → bỏ qua
#   [0001] checkpoint có → bỏ qua
#   [0002] checkpoint có → bỏ qua
#   [0003] checkpoint có → bỏ qua
#   [0004] checkpoint có → bỏ qua
#   [0005] checkpoint có → bỏ qua
#   [0006] checkpoint có → bỏ qua
#   [0007] checkpoint có → bỏ qua
#   [0008] checkpoint có → bỏ qua
#   [0009] checkpoint có → bỏ qua
#   [0010] checkpoint có → bỏ qua
#   [0011] checkpoint có → bỏ qua
#   [0012] checkpoint có → bỏ qua
#   [0013] checkpoint có → bỏ qua
#   [0014] checkpoint có → bỏ qua
#   [0015] checkpoint có → bỏ qua
#   [0016] checkpoint có → bỏ qua
#   [0017] checkpoint có → bỏ qua
#   [0018] checkpoint có → bỏ qua
#   [0019] checkpoint có → bỏ qua
#   [0020] checkpoint có → bỏ qua
#   [0021] checkpoint có → bỏ qua
#   [0022] checkpoint có → bỏ qua
#   [0023] checkpoint có → bỏ qua
#   [0024] checkpoint có → bỏ qua
#   [0025] checkpoint có → bỏ qua
#   [0026] checkpoint có → bỏ qua
#   [0027] checkpoint có → bỏ qua
#   [0028] checkpoint có → bỏ qua
#   [0029] checkpoint có → bỏ qua
#   [0030] checkpoint có → bỏ qua
#   [0031] checkpoint có → bỏ qua
#   [0032] checkpoint có → bỏ qua
#   [0033] checkpoint có → bỏ qua
#   [0034] checkpoint có → bỏ qua
#   [0035] checkpoint có → bỏ qua
#   [0036] checkpoint có → bỏ qua
#   [0037] checkpoint có → bỏ qua
#   [0038] checkpoint có → bỏ qua
#   [0039] checkpoint có → bỏ qua
#   [0040] checkpoint có → bỏ qua
#   [0041] checkpoint có → bỏ qua
#   [0042] checkpoint có → bỏ qua
#   [0043] checkpoint có → bỏ qua
#   [0044] checkpoint có → bỏ qua
#   [0045] checkpoint có → bỏ qua
#   [0046] checkpoint có → bỏ qua
#   [0047] checkpoint có → bỏ qua
#   [0048] checkpoint có → bỏ qua
#   [0049] checkpoint có → bỏ qua
#   [0050] checkpoint có → bỏ qua
#   [0051] checkpoint có → bỏ qua
#   [0052] checkpoint có → bỏ qua
#   [0053] checkpoint có → bỏ qua
#   [0054] checkpoint có → bỏ qua
#   [0055] checkpoint có → bỏ qua
#   [0056] checkpoint có → bỏ qua
#   [0057] checkpoint có → bỏ qua
#   [0058] checkpoint có → bỏ qua
#   [0059] checkpoint có → bỏ qua
#   [0060] checkpoint có → bỏ qua
#   [0061] checkpoint có → bỏ qua
#   [0062] checkpoint có → bỏ qua
#   [0063] checkpoint có → bỏ qua
#   [0064] checkpoint có → bỏ qua
#   [0065] checkpoint có → bỏ qua
#   [0066] checkpoint có → bỏ qua
#   [0067] checkpoint có → bỏ qua
#   [0068] checkpoint có → bỏ qua
#   [0069] checkpoint có → bỏ qua
#   [0070] checkpoint có → bỏ qua
#   [0071] checkpoint có → bỏ qua
#   [0072] checkpoint có → bỏ qua
#   [0073] checkpoint có → bỏ qua
#   [0074] checkpoint có → bỏ qua
#   [0075] checkpoint có → bỏ qua
#   [0076] checkpoint có → bỏ qua
#   [0077] checkpoint có → bỏ qua
#   [0078] checkpoint có → bỏ qua
#   [0079] checkpoint có → bỏ qua
#   [0080] checkpoint có → bỏ qua
#   [0081] checkpoint có → bỏ qua
#   [0082] checkpoint có → bỏ qua
#   [0083] checkpoint có → bỏ qua
#   [0084] checkpoint có → bỏ qua
#   [0085] checkpoint có → bỏ qua
#   [0086] checkpoint có → bỏ qua
#   [0087] checkpoint có → bỏ qua
#   [0088] checkpoint có → bỏ qua
#   [0089] checkpoint có → bỏ qua
#   [0090] checkpoint có → bỏ qua
#   [0091] checkpoint có → bỏ qua
#   [0092] checkpoint có → bỏ qua
#   [0093] checkpoint có → bỏ qua
#   [0094] checkpoint có → bỏ qua
#   [0095] checkpoint có → bỏ qua
#   [0096] checkpoint có → bỏ qua
#   [0097] checkpoint có → bỏ qua
#   [0098] checkpoint có → bỏ qua
#   [0099] checkpoint có → bỏ qua
#   [0100] checkpoint có → bỏ qua
#   [0101] checkpoint có → bỏ qua
#   [0102] checkpoint có → bỏ qua
#   [0103] checkpoint có → bỏ qua
#   [0104] checkpoint có → bỏ qua
#   [0105] checkpoint có → bỏ qua
#   [0106] checkpoint có → bỏ qua
#   [0107] checkpoint có → bỏ qua
#   [0108] checkpoint có → bỏ qua
#   [0109] checkpoint có → bỏ qua
#   [0110] checkpoint có → bỏ qua
#   [0111] checkpoint có → bỏ qua
#   [0112] checkpoint có → bỏ qua
#   [0113] checkpoint có → bỏ qua
#   [0114] checkpoint có → bỏ qua
#   [0115] checkpoint có → bỏ qua
#   [0116] checkpoint có → bỏ qua
#   [0117] checkpoint có → bỏ qua
#   [0118] checkpoint có → bỏ qua
#   [0119] checkpoint có → bỏ qua
#   [0120] checkpoint có → bỏ qua
#   [0121] checkpoint có → bỏ qua
#   [0122] checkpoint có → bỏ qua
#   [0123] checkpoint có → bỏ qua
#   [0124] checkpoint có → bỏ qua
#   [0125] checkpoint có → bỏ qua
#   [0126] checkpoint có → bỏ qua
#   [0127] checkpoint có → bỏ qua
#   [0128] checkpoint có → bỏ qua
#   [0129] checkpoint có → bỏ qua
#   [0130] checkpoint có → bỏ qua
#   [0131] checkpoint có → bỏ qua
#   [0132] checkpoint có → bỏ qua
#   [0133] checkpoint có → bỏ qua
#   [0134] checkpoint có → bỏ qua
#   [0135] checkpoint có → bỏ qua
#   [0136] checkpoint có → bỏ qua
#   [0137] checkpoint có → bỏ qua
#   [0138] checkpoint có → bỏ qua
#   [0139] checkpoint có → bỏ qua
#   [0140] checkpoint có → bỏ qua
#   [0141] checkpoint có → bỏ qua
#   [0142] checkpoint có → bỏ qua
#   [0143] checkpoint có → bỏ qua
#   [0144] checkpoint có → bỏ qua
#   [0145] checkpoint có → bỏ qua
#   [0146] checkpoint có → bỏ qua
#   [0147] checkpoint có → bỏ qua
#   [0148] checkpoint có → bỏ qua
#   [0149] checkpoint có → bỏ qua
#   [0150] checkpoint có → bỏ qua
#   [0151] checkpoint có → bỏ qua
#   [0152] checkpoint có → bỏ qua
#   [0153] checkpoint có → bỏ qua
#   [0154] checkpoint có → bỏ qua
#   [0155] checkpoint có → bỏ qua
#   [0156] checkpoint có → bỏ qua
#   [0157] checkpoint có → bỏ qua
#   [0158] checkpoint có → bỏ qua
#   [0159] checkpoint có → bỏ qua
#   [0160] checkpoint có → bỏ qua
#   [0161] checkpoint có → bỏ qua
#   [0162] checkpoint có → bỏ qua
#   [0163] checkpoint có → bỏ qua
#   [0164] checkpoint có → bỏ qua
#   [0165] checkpoint có → bỏ qua
#   [0166] checkpoint có → bỏ qua
#   [0167] checkpoint có → bỏ qua
#   [0168] checkpoint có → bỏ qua
#   [0169] checkpoint có → bỏ qua
#   [0170] checkpoint có → bỏ qua
#   [0171] checkpoint có → bỏ qua
#   [0172] checkpoint có → bỏ qua
#   [0173] checkpoint có → bỏ qua
#   [0174] checkpoint có → bỏ qua
#   [0175] checkpoint có → bỏ qua
#   [0176] checkpoint có → bỏ qua
#   [0177] checkpoint có → bỏ qua
#   [0178] checkpoint có → bỏ qua
#   [0179] checkpoint có → bỏ qua
#   [0180] checkpoint có → bỏ qua
#   [0181] checkpoint có → bỏ qua
#   [0182] checkpoint có → bỏ qua
#   [0183] checkpoint có → bỏ qua
#   [0184] checkpoint có → bỏ qua
#   [0185] checkpoint có → bỏ qua
#   [0186] checkpoint có → bỏ qua
#   [0187] checkpoint có → bỏ qua
#   [0188] checkpoint có → bỏ qua
#   [0189] checkpoint có → bỏ qua
#   [0190] checkpoint có → bỏ qua
#   [0191] checkpoint có → bỏ qua
#   [0192] checkpoint có → bỏ qua
#   [0193] checkpoint có → bỏ qua
#   [0194] checkpoint có → bỏ qua
#   [0195] checkpoint có → bỏ qua
#   [0196] checkpoint có → bỏ qua
#   [0197] checkpoint có → bỏ qua
#   [0198] checkpoint có → bỏ qua
#   [0199] checkpoint có → bỏ qua
#   [0200] checkpoint có → bỏ qua
#   [0201] checkpoint có → bỏ qua
#   [0202] checkpoint có → bỏ qua
#   [0203] checkpoint có → bỏ qua
#   [0204] checkpoint có → bỏ qua
#   [0205] checkpoint có → bỏ qua
#   [0206] checkpoint có → bỏ qua
#   [0207] checkpoint có → bỏ qua
#   [0208] checkpoint có → bỏ qua
#   [0209] checkpoint có → bỏ qua
#   [0210] checkpoint có → bỏ qua
#   [0211] checkpoint có → bỏ qua
#   [0212] checkpoint có → bỏ qua
#   [0213] checkpoint có → bỏ qua
#   [0214] checkpoint có → bỏ qua
#   [0215] checkpoint có → bỏ qua
#   [0216] checkpoint có → bỏ qua
#   [0217] checkpoint có → bỏ qua
#   [0218] checkpoint có → bỏ qua
#   [0219] checkpoint có → bỏ qua
#   [0220] checkpoint có → bỏ qua
#   [0221] checkpoint có → bỏ qua
#   [0222] checkpoint có → bỏ qua
#   [0223] checkpoint có → bỏ qua
#   [0224] checkpoint có → bỏ qua
#   [0225] checkpoint có → bỏ qua
#   [0226] checkpoint có → bỏ qua
#   [0227] checkpoint có → bỏ qua
#   [0228] checkpoint có → bỏ qua
#   [0229] checkpoint có → bỏ qua
#   [0230] checkpoint có → bỏ qua
#   [0231] checkpoint có → bỏ qua
#   [0232] checkpoint có → bỏ qua
#   [0233] checkpoint có → bỏ qua
#   [0234] checkpoint có → bỏ qua
#   [0235] checkpoint có → bỏ qua
#   [0236] checkpoint có → bỏ qua
#   [0237] checkpoint có → bỏ qua
#   [0238] checkpoint có → bỏ qua
#   [0239] checkpoint có → bỏ qua
#   [0240] checkpoint có → bỏ qua
#   [0241] checkpoint có → bỏ qua
#   [0242] checkpoint có → bỏ qua
#   [0243] checkpoint có → bỏ qua
#   [0244] checkpoint có → bỏ qua
#   [0245] checkpoint có → bỏ qua
#   [0246] checkpoint có → bỏ qua
#   [0247] checkpoint có → bỏ qua
#   [0248] checkpoint có → bỏ qua
#   [0249] checkpoint có → bỏ qua
#   [0250] checkpoint có → bỏ qua
#   [0251] checkpoint có → bỏ qua
#   [0252] checkpoint có → bỏ qua
#   [0253] checkpoint có → bỏ qua
#   [0254] checkpoint có → bỏ qua
#   [0255] checkpoint có → bỏ qua
#   [0256] checkpoint có → bỏ qua
#   [0257] checkpoint có → bỏ qua
#   [0258] checkpoint có → bỏ qua
#   [0259] checkpoint có → bỏ qua
#   [0260] checkpoint có → bỏ qua
#   [0261] checkpoint có → bỏ qua
#   [0262] checkpoint có → bỏ qua
#   [0263] checkpoint có → bỏ qua
#   [0264] checkpoint có → bỏ qua
#   [0265] checkpoint có → bỏ qua
#   [0266] checkpoint có → bỏ qua
#   [0267] checkpoint có → bỏ qua
#   [0268] checkpoint có → bỏ qua
#   [0269] checkpoint có → bỏ qua
#   [0270] checkpoint có → bỏ qua
#   [0271] checkpoint có → bỏ qua
#   [0272] checkpoint có → bỏ qua
#   [0273] checkpoint có → bỏ qua
#   [0274] checkpoint có → bỏ qua
#   [0275] checkpoint có → bỏ qua
#   [0276] checkpoint có → bỏ qua
#   [0277] checkpoint có → bỏ qua
#   [0278] checkpoint có → bỏ qua
#   [0279] checkpoint có → bỏ qua
#   [0280] checkpoint có → bỏ qua
#   [0281] checkpoint có → bỏ qua
#   [0282] checkpoint có → bỏ qua
#   [0283] checkpoint có → bỏ qua
#   [0284] checkpoint có → bỏ qua
#   [0285] checkpoint có → bỏ qua
#   [0286] checkpoint có → bỏ qua
#   [0287] checkpoint có → bỏ qua
#   [0288] checkpoint có → bỏ qua
#   [0289] checkpoint có → bỏ qua
#   [0290] checkpoint có → bỏ qua
#   [0291] checkpoint có → bỏ qua
#   [0292] checkpoint có → bỏ qua
#   [0293] checkpoint có → bỏ qua
#   [0294] checkpoint có → bỏ qua
#   [0295] checkpoint có → bỏ qua
#   [0296] checkpoint có → bỏ qua
#   [0297] checkpoint có → bỏ qua
#   [0298] checkpoint có → bỏ qua
#   [0299] checkpoint có → bỏ qua
#   [0300] checkpoint có → bỏ qua
#   [0301] checkpoint có → bỏ qua
#   [0302] checkpoint có → bỏ qua
#   [0303] checkpoint có → bỏ qua
#   [0304] checkpoint có → bỏ qua
#   [0305] checkpoint có → bỏ qua
#   [0306] checkpoint có → bỏ qua
#   [0307] checkpoint có → bỏ qua
#   [0308] checkpoint có → bỏ qua
#   [0309] checkpoint có → bỏ qua
#   [0310] checkpoint có → bỏ qua
#   [0311] checkpoint có → bỏ qua
#   [0312] checkpoint có → bỏ qua
#   [0313] checkpoint có → bỏ qua
#   [0314] checkpoint có → bỏ qua
#   [0315] checkpoint có → bỏ qua
#   [0316] checkpoint có → bỏ qua
#   [0317] checkpoint có → bỏ qua
#   [0318] checkpoint có → bỏ qua
#   [0319] checkpoint có → bỏ qua
#   [0320] checkpoint có → bỏ qua
#   [0321] checkpoint có → bỏ qua
#   [0322] checkpoint có → bỏ qua
#   [0323] checkpoint có → bỏ qua
#   [0324] checkpoint có → bỏ qua
#   [0325] checkpoint có → bỏ qua
#   [0326] checkpoint có → bỏ qua
#   [0327] checkpoint có → bỏ qua
#   [0328] checkpoint có → bỏ qua
#   [0329] checkpoint có → bỏ qua
#   [0330] checkpoint có → bỏ qua
#   [0331] checkpoint có → bỏ qua
#   [0332] checkpoint có → bỏ qua
#   [0333] checkpoint có → bỏ qua
#   [0334] checkpoint có → bỏ qua
#   [0335] checkpoint có → bỏ qua
#   [0336] checkpoint có → bỏ qua
#   [0337] checkpoint có → bỏ qua
#   [0338] checkpoint có → bỏ qua
#   [0339] checkpoint có → bỏ qua
#   [0340] checkpoint có → bỏ qua
#   [0341] checkpoint có → bỏ qua
#   [0342] checkpoint có → bỏ qua
#   [0343] checkpoint có → bỏ qua
#   [0344] checkpoint có → bỏ qua
#   [0345] checkpoint có → bỏ qua
#   [0346] checkpoint có → bỏ qua
#   [0347] checkpoint có → bỏ qua
#   [0348] checkpoint có → bỏ qua
#   [0349] checkpoint có → bỏ qua
#   [0350] checkpoint có → bỏ qua
#   [0351] checkpoint có → bỏ qua
#   [0352] checkpoint có → bỏ qua
#   [0353] checkpoint có → bỏ qua
#   [0354] checkpoint có → bỏ qua
#   [0355] checkpoint có → bỏ qua
#   [0356] checkpoint có → bỏ qua
#   [0357] checkpoint có → bỏ qua
#   [0358] checkpoint có → bỏ qua
#   [0359] checkpoint có → bỏ qua
#   [0360] checkpoint có → bỏ qua
#   [0361] checkpoint có → bỏ qua
#   [0362] checkpoint có → bỏ qua
#   [0363] checkpoint có → bỏ qua
#   [0364] checkpoint có → bỏ qua
#   [0365] checkpoint có → bỏ qua
#   [0366] checkpoint có → bỏ qua
#   [0367] checkpoint có → bỏ qua
#   [0368] checkpoint có → bỏ qua
#   [0369] checkpoint có → bỏ qua
#   [0370] checkpoint có → bỏ qua
#   [0371] checkpoint có → bỏ qua
#   [0372] checkpoint có → bỏ qua
#   [0373] checkpoint có → bỏ qua
#   [0374] checkpoint có → bỏ qua
#   [0375] checkpoint có → bỏ qua
#   [0376] checkpoint có → bỏ qua
#   [0377] checkpoint có → bỏ qua
#   [0378] checkpoint có → bỏ qua
#   [0379] checkpoint có → bỏ qua
#   [0380] checkpoint có → bỏ qua
#   [0381] checkpoint có → bỏ qua
#   [0382] checkpoint có → bỏ qua
#   [0383] checkpoint có → bỏ qua
#   [0384] checkpoint có → bỏ qua
#   [0385] checkpoint có → bỏ qua
#   [0386] checkpoint có → bỏ qua
#   [0387] checkpoint có → bỏ qua
#   [0388] checkpoint có → bỏ qua
#   [0389] checkpoint có → bỏ qua
#   [0390] checkpoint có → bỏ qua
#   [0391] checkpoint có → bỏ qua
#   [0392] checkpoint có → bỏ qua
#   [0393] checkpoint có → bỏ qua
#   [0394] checkpoint có → bỏ qua
#   [0395] checkpoint có → bỏ qua
#   [0396] checkpoint có → bỏ qua
#   [0397] checkpoint có → bỏ qua
#   [0398] checkpoint có → bỏ qua
#   [0399] checkpoint có → bỏ qua
#   [0400] checkpoint có → bỏ qua
#   [0401] checkpoint có → bỏ qua
#   [0402] checkpoint có → bỏ qua
#   [0403] checkpoint có → bỏ qua
#   [0404] checkpoint có → bỏ qua
#   [0405] checkpoint có → bỏ qua
#   [0406] checkpoint có → bỏ qua
#   [0407] checkpoint có → bỏ qua
#   [0408] checkpoint có → bỏ qua
#   [0409] checkpoint có → bỏ qua
#   [0410] checkpoint có → bỏ qua
#   [0411] checkpoint có → bỏ qua
#   [0412] checkpoint có → bỏ qua
#   [0413] checkpoint có → bỏ qua
#   [0414] checkpoint có → bỏ qua
#   [0415] checkpoint có → bỏ qua
#   [0416] checkpoint có → bỏ qua
#   [0417] checkpoint có → bỏ qua
#   [0418] checkpoint có → bỏ qua
#   [0419] checkpoint có → bỏ qua
#   [0420] checkpoint có → bỏ qua
#   [0421] checkpoint có → bỏ qua
#   [0422] checkpoint có → bỏ qua
#   [0423] checkpoint có → bỏ qua
#   [0424] checkpoint có → bỏ qua
#   [0425] checkpoint có → bỏ qua
#   [0426] checkpoint có → bỏ qua
#   [0427] checkpoint có → bỏ qua
#   [0428] checkpoint có → bỏ qua
#   [0429] checkpoint có → bỏ qua
#   [0430] checkpoint có → bỏ qua
#   [0431] checkpoint có → bỏ qua
#   [0432] checkpoint có → bỏ qua
#   [0433] checkpoint có → bỏ qua
#   [0434] checkpoint có → bỏ qua
#   [0435] checkpoint có → bỏ qua
#   [0436] checkpoint có → bỏ qua
#   [0437] checkpoint có → bỏ qua
#   [0438] checkpoint có → bỏ qua
#   [0439] checkpoint có → bỏ qua
#   [0440] checkpoint có → bỏ qua
#   [0441] checkpoint có → bỏ qua
#   [0442] checkpoint có → bỏ qua
#   [0443] checkpoint có → bỏ qua
#   [0444] checkpoint có → bỏ qua
#   [0445] checkpoint có → bỏ qua
#   [0446] checkpoint có → bỏ qua
#   [0447] checkpoint có → bỏ qua
#   [0448] checkpoint có → bỏ qua
#   [0449] checkpoint có → bỏ qua
#   [0450] checkpoint có → bỏ qua
#   [0451] checkpoint có → bỏ qua
#   [0452] checkpoint có → bỏ qua
#   [0453] checkpoint có → bỏ qua
#   [0454] checkpoint có → bỏ qua
#   [0455] checkpoint có → bỏ qua
#   [0456] checkpoint có → bỏ qua
#   [0457] checkpoint có → bỏ qua
#   [0458] checkpoint có → bỏ qua
#   [0459] checkpoint có → bỏ qua
#   [0460] checkpoint có → bỏ qua
#   [0461] checkpoint có → bỏ qua
#   [0462] checkpoint có → bỏ qua
#   [0463] checkpoint có → bỏ qua
#   [0464] checkpoint có → bỏ qua
#   [0465] checkpoint có → bỏ qua
#   [0466] checkpoint có → bỏ qua
#   [0467] checkpoint có → bỏ qua
#   [0468] checkpoint có → bỏ qua
#   [0469] checkpoint có → bỏ qua
#   [0470] checkpoint có → bỏ qua
#   [0471] checkpoint có → bỏ qua
#   [0472] checkpoint có → bỏ qua
#   [0473] checkpoint có → bỏ qua
#   [0474] checkpoint có → bỏ qua
#   [0475] checkpoint có → bỏ qua
#   [0476] checkpoint có → bỏ qua
#   [0477] checkpoint có → bỏ qua
#   [0478] checkpoint có → bỏ qua
#   [0479] checkpoint có → bỏ qua
#   [0480] checkpoint có → bỏ qua
#   [0481] checkpoint có → bỏ qua
#   [0482] checkpoint có → bỏ qua
#   [0483] checkpoint có → bỏ qua
#   [0484] checkpoint có → bỏ qua
#   [0485] checkpoint có → bỏ qua
#   [0486] checkpoint có → bỏ qua
#   [0487] checkpoint có → bỏ qua
#   [0488] checkpoint có → bỏ qua
#   [0489] checkpoint có → bỏ qua
#   [0490] checkpoint có → bỏ qua
#   [0491] checkpoint có → bỏ qua
#   [0492] checkpoint có → bỏ qua
#   [0493] checkpoint có → bỏ qua
#   [0494] checkpoint có → bỏ qua
#   [0495] checkpoint có → bỏ qua
#   [0496] checkpoint có → bỏ qua
#   [0497] checkpoint có → bỏ qua
#   [0498] checkpoint có → bỏ qua
#   [0499] checkpoint có → bỏ qua
#   [0500] checkpoint có → bỏ qua
#   [0501] checkpoint có → bỏ qua
#   [0502] checkpoint có → bỏ qua
#   [0503] checkpoint có → bỏ qua
#   [0504] checkpoint có → bỏ qua
#   [0505] checkpoint có → bỏ qua
#   [0506] checkpoint có → bỏ qua
#   [0507] checkpoint có → bỏ qua
#   [0508] checkpoint có → bỏ qua
#   [0509] checkpoint có → bỏ qua
#   [0510] checkpoint có → bỏ qua
#   [0511] checkpoint có → bỏ qua
#   [0512] checkpoint có → bỏ qua
#   [0513] checkpoint có → bỏ qua
#   [0514] checkpoint có → bỏ qua
#   [0515] checkpoint có → bỏ qua
#   [0516] checkpoint có → bỏ qua
#   [0517] checkpoint có → bỏ qua
#   [0518] checkpoint có → bỏ qua
#   [0519] checkpoint có → bỏ qua
#   [0520] checkpoint có → bỏ qua
#   [0521] checkpoint có → bỏ qua
#   [0522] checkpoint có → bỏ qua
#   [0523] checkpoint có → bỏ qua
#   [0524] checkpoint có → bỏ qua
#   [0525] checkpoint có → bỏ qua
#   [0526] checkpoint có → bỏ qua
#   [0527] checkpoint có → bỏ qua
#   [0528] checkpoint có → bỏ qua
#   [0529] checkpoint có → bỏ qua
#   [0530] checkpoint có → bỏ qua
#   [0531] checkpoint có → bỏ qua
#   [0532] checkpoint có → bỏ qua
#   [0533] checkpoint có → bỏ qua
#   [0534] checkpoint có → bỏ qua
#   [0535] checkpoint có → bỏ qua
#   [0536] checkpoint có → bỏ qua
#   [0537] checkpoint có → bỏ qua
#   [0538] checkpoint có → bỏ qua
#   [0539] checkpoint có → bỏ qua
#   [0540] checkpoint có → bỏ qua
#   [0541] checkpoint có → bỏ qua
#   [0542] checkpoint có → bỏ qua
#   [0543] checkpoint có → bỏ qua
#   [0544] checkpoint có → bỏ qua
#   [0545] checkpoint có → bỏ qua
#   [0546] checkpoint có → bỏ qua
#   [0547] checkpoint có → bỏ qua
#   [0548] checkpoint có → bỏ qua
#   [0549] checkpoint có → bỏ qua
#   [0550] checkpoint có → bỏ qua
#   [0551] checkpoint có → bỏ qua
#   [0552] checkpoint có → bỏ qua
#   [0553] checkpoint có → bỏ qua
#   [0554] checkpoint có → bỏ qua
#   [0555] checkpoint có → bỏ qua
#   [0556] checkpoint có → bỏ qua
#   [0557] checkpoint có → bỏ qua
#   [0558] checkpoint có → bỏ qua
#   [0559] checkpoint có → bỏ qua
#   [0560] checkpoint có → bỏ qua
#   [0561] checkpoint có → bỏ qua
#   [0562] checkpoint có → bỏ qua
#   [0563] checkpoint có → bỏ qua
#   [0564] checkpoint có → bỏ qua
#   [0565] checkpoint có → bỏ qua
#   [0566] checkpoint có → bỏ qua
#   [0567] checkpoint có → bỏ qua
#   [0568] checkpoint có → bỏ qua
#   [0569] checkpoint có → bỏ qua
#   [0570] checkpoint có → bỏ qua
#   [0571] checkpoint có → bỏ qua
#   [0572] checkpoint có → bỏ qua
#   [0573] checkpoint có → bỏ qua
#   [0574] checkpoint có → bỏ qua
#   [0575] checkpoint có → bỏ qua
#   [0576] checkpoint có → bỏ qua
#   [0577] checkpoint có → bỏ qua
#   [0578] checkpoint có → bỏ qua
#   [0579] checkpoint có → bỏ qua
#   [0580] checkpoint có → bỏ qua
#   [0581] checkpoint có → bỏ qua
#   [0582] checkpoint có → bỏ qua
#   [0583] checkpoint có → bỏ qua
#   [0584] checkpoint có → bỏ qua
#   [0585] checkpoint có → bỏ qua
#   [0586] checkpoint có → bỏ qua
#   [0587] checkpoint có → bỏ qua
#   [0588] checkpoint có → bỏ qua
#   [0589] checkpoint có → bỏ qua
#   [0590] checkpoint có → bỏ qua
#   [0591] checkpoint có → bỏ qua
#   [0592] checkpoint có → bỏ qua
#   [0593] checkpoint có → bỏ qua
#   [0594] checkpoint có → bỏ qua
#   [0595] checkpoint có → bỏ qua
#   [0596] checkpoint có → bỏ qua
#   [0597] checkpoint có → bỏ qua
#   [0598] checkpoint có → bỏ qua
#   [0599] checkpoint có → bỏ qua
#   [0600] checkpoint có → bỏ qua
#   [0601] checkpoint có → bỏ qua
#   [0602] checkpoint có → bỏ qua
#   [0603] checkpoint có → bỏ qua
#   [0604] checkpoint có → bỏ qua
#   [0605] checkpoint có → bỏ qua
#   [0606] checkpoint có → bỏ qua
#   [0607] checkpoint có → bỏ qua
#   [0608] checkpoint có → bỏ qua
#   [0609] checkpoint có → bỏ qua
#   [0610] checkpoint có → bỏ qua
#   [0611] checkpoint có → bỏ qua
#   [0612] checkpoint có → bỏ qua
#   [0613] checkpoint có → bỏ qua
#   [0614] checkpoint có → bỏ qua
#   [0615] checkpoint có → bỏ qua
#   [0616] checkpoint có → bỏ qua
#   [0617] checkpoint có → bỏ qua
#   [0618] checkpoint có → bỏ qua
#   [0619] checkpoint có → bỏ qua
#   [0620] checkpoint có → bỏ qua
#   [0621] checkpoint có → bỏ qua
#   [0622] checkpoint có → bỏ qua
#   [0623] checkpoint có → bỏ qua
#   [0624] checkpoint có → bỏ qua
#   [0625] checkpoint có → bỏ qua
#   [0626] checkpoint có → bỏ qua
#   [0627] checkpoint có → bỏ qua
#   [0628] checkpoint có → bỏ qua
#   [0629] checkpoint có → bỏ qua
#   [0630] checkpoint có → bỏ qua
#   [0631] checkpoint có → bỏ qua
#   [0632] checkpoint có → bỏ qua
#   [0633] checkpoint có → bỏ qua
#   [0634] checkpoint có → bỏ qua
#   [0635] checkpoint có → bỏ qua
#   [0636] checkpoint có → bỏ qua
#   [0637] checkpoint có → bỏ qua
#   [0638] checkpoint có → bỏ qua
#   [0639] checkpoint có → bỏ qua
#   [0640] checkpoint có → bỏ qua
#   [0641] checkpoint có → bỏ qua
#   [0642] checkpoint có → bỏ qua
#   [0643] checkpoint có → bỏ qua
#   [0644] checkpoint có → bỏ qua
#   [0645] checkpoint có → bỏ qua
#   [0646] checkpoint có → bỏ qua
#   [0647] checkpoint có → bỏ qua
#   [0648] checkpoint có → bỏ qua
#   [0649] checkpoint có → bỏ qua
#   [0650] checkpoint có → bỏ qua
#   [0651] checkpoint có → bỏ qua
#   [0652] checkpoint có → bỏ qua
#   [0653] checkpoint có → bỏ qua
#   [0654] checkpoint có → bỏ qua
#   [0655] checkpoint có → bỏ qua
#   [0656] checkpoint có → bỏ qua
#   [0657] checkpoint có → bỏ qua
#   [0658] checkpoint có → bỏ qua
#   [0659] checkpoint có → bỏ qua
#   [0660] checkpoint có → bỏ qua
#   [0661] checkpoint có → bỏ qua
#   [0662] checkpoint có → bỏ qua
#   [0663] checkpoint có → bỏ qua
#   [0664] checkpoint có → bỏ qua
#
#   Gộp review_meta...
# Bước 7.2 hoàn thành!

# %%
print("\n" + "="*60)
print("BƯỚC 7.3 — Build user semantic profiles (checkpoint + batch)")
print("="*60)

USER_BATCH_SIZE = 50_000   # số user xử lý mỗi lần, giảm nếu vẫn tràn RAM

USER_CKPT_DIR = OUTPUT_DIR / "user_ckpts/"
USER_CKPT_DIR.mkdir(exist_ok=True)
# [1/4] Build item lookup: asin → numpy row index
# Gộp tất cả item_ids_XXXX.parquet → biết asin nằm ở chunk nào, row nào
print("\n[1/4] Build item lookup từ checkpoint 7.1...")
ckpt_id_files  = sorted(CHECKPOINT_DIR.glob("item_ids_*.parquet"))
ckpt_emb_files = sorted(CHECKPOINT_DIR.glob("item_profiles_*.npy"))
assert len(ckpt_id_files) == len(ckpt_emb_files), "Số checkpoint ids và emb không khớp!"

# Xây dựng: asin → (chunk_idx, row_idx_within_chunk)
asin_to_loc = {}   # {asin: (chunk_idx, local_row)}
for chunk_idx, id_file in enumerate(ckpt_id_files):
    ids = pd.read_parquet(id_file)["parent_asin"].tolist()
    for local_row, asin in enumerate(ids):
        asin_to_loc[asin] = (chunk_idx, local_row)

print(f"  Item lookup: {len(asin_to_loc):,} items từ {len(ckpt_id_files)} chunks")

# mmap array cho từng chunk — OS tự quản lý, không load vào RAM
mmap_chunks = [
    np.load(str(f), mmap_mode="r") for f in ckpt_emb_files
]
dim = mmap_chunks[0].shape[1]
print(f"  Embedding dim: {dim}")

def get_item_vec(asin: str):
    loc = asin_to_loc.get(asin)
    if loc is None:
        return None
    chunk_idx, local_row = loc
    # Slice mmap → chỉ đọc đúng 1 row từ disk
    return np.array(mmap_chunks[chunk_idx][local_row], dtype="float32")

# [2/4] Load review_meta + tính recency
print("\n[2/4] Load review_meta + tính recency_decay...")
df_meta = pd.read_parquet(OUTPUT_DIR / "review_meta.parquet")
print(f"  review_meta: {len(df_meta):,} rows")

sample = df_meta["review_time"].iloc[0]
if isinstance(sample, (int, float, np.integer, np.floating)):
    df_meta["review_time"] = pd.to_datetime(df_meta["review_time"], unit="s")
else:
    df_meta["review_time"] = pd.to_datetime(df_meta["review_time"])

max_date = df_meta["review_time"].max()
print(f"  Mốc cuối train: {max_date.date()}")

df_meta["days_ago"]      = (max_date - df_meta["review_time"]).dt.days.clip(lower=0)
df_meta["recency_decay"] = np.exp(-LAMBDA * df_meta["days_ago"])

# [3/4] Xử lý user theo batch, checkpoint sau mỗi batch
print(f"\n[3/4] Build profiles (BETA={BETA}, λ={LAMBDA}, N_RECENT={N_RECENT})...")
print(f"  Batch size: {USER_BATCH_SIZE:,} users/batch")

# Tìm batch đã xong để resume
done_batch_files = sorted(USER_CKPT_DIR.glob("batch_*.parquet"))
done_batches     = {int(f.stem.split("_")[1]) for f in done_batch_files}
if done_batches:
    print(f"  Resume: đã xong {len(done_batches)} batch, tiếp tục từ batch {max(done_batches)+1}")

all_user_ids = sorted(df_meta["reviewer_id"].unique())
total_users  = len(all_user_ids)
print(f"  Tổng users: {total_users:,}")

n_batches = (total_users + USER_BATCH_SIZE - 1) // USER_BATCH_SIZE

for batch_idx in range(n_batches):
    if batch_idx in done_batches:
        print(f"  Batch {batch_idx:04d}/{n_batches} → đã có checkpoint, bỏ qua")
        continue

    batch_start = batch_idx * USER_BATCH_SIZE
    batch_end   = min(batch_start + USER_BATCH_SIZE, total_users)
    batch_users = set(all_user_ids[batch_start:batch_end])

    print(f"\n  Batch {batch_idx:04d}/{n_batches} "
          f"(user {batch_start:,}–{batch_end:,})...")

    # Lọc df_meta chỉ lấy batch này — tránh groupby toàn bộ
    df_batch = df_meta[df_meta["reviewer_id"].isin(batch_users)].copy()

    batch_ids  = []
    batch_embs = []

    for user_id, grp in df_batch.groupby("reviewer_id"):
        # Lấy item vectors cho user này
        item_cache = {}
        for asin in grp["parent_asin"].unique():
            v = get_item_vec(asin)
            if v is not None:
                item_cache[asin] = v

        if not item_cache:
            continue

        valid = grp[grp["parent_asin"].isin(item_cache)]

        # Long-term: w = reliability * recency_decay
        lt_w  = valid["reliability_score"].values * valid["recency_decay"].values
        lt_w  = lt_w / (lt_w.sum() + 1e-9)
        lt_v  = np.stack([item_cache[a] for a in valid["parent_asin"]])
        long_term = (lt_v * lt_w[:, None]).sum(axis=0)

        # Recent: top-N gần nhất, w = strength_score
        recent_rows = valid.nlargest(N_RECENT, "review_time")
        rc_w  = recent_rows["strength_score"].values
        rc_w  = rc_w / (rc_w.sum() + 1e-9)
        rc_v  = np.stack([item_cache[a] for a in recent_rows["parent_asin"]])
        recent = (rc_v * rc_w[:, None]).sum(axis=0)

        # Blend + L2 normalize
        user_vec = BETA * recent + (1 - BETA) * long_term
        user_vec = l2_normalize(user_vec).astype("float32")

        batch_ids.append(user_id)
        batch_embs.append(user_vec)

    # Lưu checkpoint batch
    if batch_embs:
        batch_arr = np.stack(batch_embs)
        ckpt_path = USER_CKPT_DIR / f"batch_{batch_idx:04d}.parquet"
        # Lưu emb inline trong parquet dưới dạng list (nhỏ gọn, dễ gộp)
        pd.DataFrame({
            "reviewer_id": batch_ids,
            "embedding":   [v.tolist() for v in batch_arr]
        }).to_parquet(ckpt_path, index=False)
        print(f"    Saved {len(batch_ids):,} users → batch_{batch_idx:04d}.parquet")

    del df_batch, batch_ids, batch_embs; gc.collect()

# [4/4] Gộp tất cả batch checkpoint → file cuối
print("\n[4/4] Gộp tất cả batch checkpoints...")

batch_files = sorted(USER_CKPT_DIR.glob("batch_*.parquet"))

# Đếm tổng số user trước để pre-allocate array 1 lần
total = sum(len(pd.read_parquet(f, columns=["reviewer_id"])) for f in batch_files)
print(f"  Tổng users: {total:,}")

user_arr     = np.zeros((total, dim), dtype="float32")
reviewer_ids = []
cursor       = 0

for f in batch_files:
    df_part = pd.read_parquet(f)
    n = len(df_part)
    user_arr[cursor:cursor+n] = np.stack(
        df_part["embedding"].apply(np.array).values
    ).astype("float32")
    reviewer_ids.extend(df_part["reviewer_id"].tolist())
    cursor += n
    del df_part; gc.collect()

np.save(OUTPUT_DIR / "user_semantic_profiles_v1.npy", user_arr)
pd.DataFrame({
    "reviewer_id": reviewer_ids,
    "profile_pos": range(len(reviewer_ids))
}).to_parquet(OUTPUT_DIR / "user_id_map_v1.parquet", index=False)

print(f"  Saved: user_semantic_profiles_v1.npy  shape={user_arr.shape}")
print(f"  Saved: user_id_map_v1.parquet")
print("\nBước 7.3 hoàn thành!")
print("\nOutput trong semantic/:")
# Out:
# ============================================================
# BƯỚC 7.3 — Build user semantic profiles (checkpoint + batch)
# ============================================================
#
# [1/4] Build item lookup từ checkpoint 7.1...
#   Item lookup: 1,602,487 items từ 665 chunks
#   Embedding dim: 384
#
# [2/4] Load review_meta + tính recency_decay...
#   review_meta: 8,327,078 rows
#   Mốc cuối train: 2023-06-30
#
# [3/4] Build profiles (BETA=0.6, λ=0.01, N_RECENT=20)...
#   Batch size: 50,000 users/batch
#   Resume: đã xong 86 batch, tiếp tục từ batch 86
#   Tổng users: 4,251,444
#   Batch 0000/86 → đã có checkpoint, bỏ qua
#   Batch 0001/86 → đã có checkpoint, bỏ qua
#   Batch 0002/86 → đã có checkpoint, bỏ qua
#   Batch 0003/86 → đã có checkpoint, bỏ qua
#   Batch 0004/86 → đã có checkpoint, bỏ qua
#   Batch 0005/86 → đã có checkpoint, bỏ qua
#   Batch 0006/86 → đã có checkpoint, bỏ qua
#   Batch 0007/86 → đã có checkpoint, bỏ qua
#   Batch 0008/86 → đã có checkpoint, bỏ qua
#   Batch 0009/86 → đã có checkpoint, bỏ qua
#   Batch 0010/86 → đã có checkpoint, bỏ qua
#   Batch 0011/86 → đã có checkpoint, bỏ qua
#   Batch 0012/86 → đã có checkpoint, bỏ qua
#   Batch 0013/86 → đã có checkpoint, bỏ qua
#   Batch 0014/86 → đã có checkpoint, bỏ qua
#   Batch 0015/86 → đã có checkpoint, bỏ qua
#   Batch 0016/86 → đã có checkpoint, bỏ qua
#   Batch 0017/86 → đã có checkpoint, bỏ qua
#   Batch 0018/86 → đã có checkpoint, bỏ qua
#   Batch 0019/86 → đã có checkpoint, bỏ qua
#   Batch 0020/86 → đã có checkpoint, bỏ qua
#   Batch 0021/86 → đã có checkpoint, bỏ qua
#   Batch 0022/86 → đã có checkpoint, bỏ qua
#   Batch 0023/86 → đã có checkpoint, bỏ qua
#   Batch 0024/86 → đã có checkpoint, bỏ qua
#   Batch 0025/86 → đã có checkpoint, bỏ qua
#   Batch 0026/86 → đã có checkpoint, bỏ qua
#   Batch 0027/86 → đã có checkpoint, bỏ qua
#   Batch 0028/86 → đã có checkpoint, bỏ qua
#   Batch 0029/86 → đã có checkpoint, bỏ qua
#   Batch 0030/86 → đã có checkpoint, bỏ qua
#   Batch 0031/86 → đã có checkpoint, bỏ qua
#   Batch 0032/86 → đã có checkpoint, bỏ qua
#   Batch 0033/86 → đã có checkpoint, bỏ qua
#   Batch 0034/86 → đã có checkpoint, bỏ qua
#   Batch 0035/86 → đã có checkpoint, bỏ qua
#   Batch 0036/86 → đã có checkpoint, bỏ qua
#   Batch 0037/86 → đã có checkpoint, bỏ qua
#   Batch 0038/86 → đã có checkpoint, bỏ qua
#   Batch 0039/86 → đã có checkpoint, bỏ qua
#   Batch 0040/86 → đã có checkpoint, bỏ qua
#   Batch 0041/86 → đã có checkpoint, bỏ qua
#   Batch 0042/86 → đã có checkpoint, bỏ qua
#   Batch 0043/86 → đã có checkpoint, bỏ qua
#   Batch 0044/86 → đã có checkpoint, bỏ qua
#   Batch 0045/86 → đã có checkpoint, bỏ qua
#   Batch 0046/86 → đã có checkpoint, bỏ qua
#   Batch 0047/86 → đã có checkpoint, bỏ qua
#   Batch 0048/86 → đã có checkpoint, bỏ qua
#   Batch 0049/86 → đã có checkpoint, bỏ qua
#   Batch 0050/86 → đã có checkpoint, bỏ qua
#   Batch 0051/86 → đã có checkpoint, bỏ qua
#   Batch 0052/86 → đã có checkpoint, bỏ qua
#   Batch 0053/86 → đã có checkpoint, bỏ qua
#   Batch 0054/86 → đã có checkpoint, bỏ qua
#   Batch 0055/86 → đã có checkpoint, bỏ qua
#   Batch 0056/86 → đã có checkpoint, bỏ qua
#   Batch 0057/86 → đã có checkpoint, bỏ qua
#   Batch 0058/86 → đã có checkpoint, bỏ qua
#   Batch 0059/86 → đã có checkpoint, bỏ qua
#   Batch 0060/86 → đã có checkpoint, bỏ qua
#   Batch 0061/86 → đã có checkpoint, bỏ qua
#   Batch 0062/86 → đã có checkpoint, bỏ qua
#   Batch 0063/86 → đã có checkpoint, bỏ qua
#   Batch 0064/86 → đã có checkpoint, bỏ qua
#   Batch 0065/86 → đã có checkpoint, bỏ qua
#   Batch 0066/86 → đã có checkpoint, bỏ qua
#   Batch 0067/86 → đã có checkpoint, bỏ qua
#   Batch 0068/86 → đã có checkpoint, bỏ qua
#   Batch 0069/86 → đã có checkpoint, bỏ qua
#   Batch 0070/86 → đã có checkpoint, bỏ qua
#   Batch 0071/86 → đã có checkpoint, bỏ qua
#   Batch 0072/86 → đã có checkpoint, bỏ qua
#   Batch 0073/86 → đã có checkpoint, bỏ qua
#   Batch 0074/86 → đã có checkpoint, bỏ qua
#   Batch 0075/86 → đã có checkpoint, bỏ qua
#   Batch 0076/86 → đã có checkpoint, bỏ qua
#   Batch 0077/86 → đã có checkpoint, bỏ qua
#   Batch 0078/86 → đã có checkpoint, bỏ qua
#   Batch 0079/86 → đã có checkpoint, bỏ qua
#   Batch 0080/86 → đã có checkpoint, bỏ qua
#   Batch 0081/86 → đã có checkpoint, bỏ qua
#   Batch 0082/86 → đã có checkpoint, bỏ qua
#   Batch 0083/86 → đã có checkpoint, bỏ qua
#   Batch 0084/86 → đã có checkpoint, bỏ qua
#   Batch 0085/86 → đã có checkpoint, bỏ qua
#
# [4/4] Gộp tất cả batch checkpoints...
#   Tổng users: 4,251,444
#   Saved: user_semantic_profiles_v1.npy  shape=(4251444, 384)
#   Saved: user_id_map_v1.parquet
#
# Bước 7.3 hoàn thành!
#
# Output trong semantic/:
